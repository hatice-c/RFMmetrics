# %%
import pandas as pd
import numpy as np
import seaborn as sns

# to display all columns and rows:
pd.set_option('display.max_columns', None); pd.set_option('display.max_rows', None);

#virgulden sonra gösterilecek olan sayı sayısı
pd.set_option('display.float_format', lambda x: '%.0f' % x)
import matplotlib.pyplot as plt

# %%
df_2010_2011 = pd.read_excel("../input/uci-online-retail-ii-data-set/online_retail_II.xlsx", sheet_name = "Year 2010-2011")

# %%
df = df_2010_2011.copy()

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2010-12-01 08:26:00      3        17850  United Kingdom
# 1 2010-12-01 08:26:00      3        17850  United Kingdom
# 2 2010-12-01 08:26:00      3        17850  United Kingdom
# 3 2010-12-01 08:26:00      3        17850  United Kingdom
# 4 2010-12-01 08:26:00      3        17850  United Kingdom

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2010-12-01 08:26:00      3        17850  United Kingdom
# 1 2010-12-01 08:26:00      3        17850  United Kingdom
# 2 2010-12-01 08:26:00      3        17850  United Kingdom
# 3 2010-12-01 08:26:00      3        17850  United Kingdom
# 4 2010-12-01 08:26:00      3        17850  United Kingdom

# %%
#df.groupby("Invoice").agg({"TotalPrice":"sum"}).head()

# %%
df["TotalPrice"] = df["Quantity"]*df["Price"]

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    135080
# Country             0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.describe([0.01,0.05,0.10,0.25,0.50,0.75,0.90,0.95, 0.99]).T
# Out:
#              count  mean  std    min    1%    5%   10%   25%   50%   75%  \
# Quantity    406830    12  249 -80995    -2     1     1     2     5    12
# Price       406830     3   69      0     0     0     1     1     2     4
# Customer ID 406830 15288 1714  12346 12415 12626 12876 13953 15152 16791
#
#               90%   95%   99%   max
# Quantity       24    36   120 80995
# Price           7     8    15 38970
# Customer ID 17719 17905 18212 18287

# %%
for feature in ["Quantity","Price","TotalPrice"]:

    Q1 = df[feature].quantile(0.01)
    Q3 = df[feature].quantile(0.99)
    IQR = Q3-Q1
    upper = Q3 + 1.5*IQR
    lower = Q1 - 1.5*IQR

    if df[(df[feature] > upper) | (df[feature] < lower)].any(axis=None):
        print(feature,"yes")
        print(df[(df[feature] > upper) | (df[feature] < lower)].shape[0])
    else:
        print(feature, "no")
# Out:
# Quantity yes
# 948
# Price yes
# 846
# TotalPrice yes
# 1030

# %%
df["InvoiceDate"].min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
df["InvoiceDate"].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
import datetime as dt
today_date = dt.datetime(2011,12,9)

# %%
df.groupby("Customer ID").agg({"InvoiceDate":"max"}).head()
# Out:
#                     InvoiceDate
# Customer ID
# 12346       2011-01-18 10:17:00
# 12347       2011-12-07 15:52:00
# 12348       2011-09-25 13:13:00
# 12349       2011-11-21 09:51:00
# 12350       2011-02-02 16:01:00

# %%
df.groupby("Customer ID").agg({"InvoiceDate":"max"}).head()
# Out:
#                     InvoiceDate
# Customer ID
# 12346       2011-01-18 10:17:00
# 12347       2011-12-07 15:52:00
# 12348       2011-09-25 13:13:00
# 12349       2011-11-21 09:51:00
# 12350       2011-02-02 16:01:00

# %%
df["Customer ID"] = df["Customer ID"].astype(int)

# %%
(today_date - df.groupby("Customer ID").agg({"InvoiceDate":"max"})).head()
# Out:
#                   InvoiceDate
# Customer ID
# 12346       324 days 13:43:00
# 12347         1 days 08:08:00
# 12348        74 days 10:47:00
# 12349        17 days 14:09:00
# 12350       309 days 07:59:00

# %%
temp_df = (today_date - df.groupby("Customer ID").agg({"InvoiceDate":"max"}))

# %%
temp_df.rename(columns={"InvoiceDate": "Recency"}, inplace = True)

# %%
temp_df.head()
# Out:
#                       Recency
# Customer ID
# 12346       324 days 13:43:00
# 12347         1 days 08:08:00
# 12348        74 days 10:47:00
# 12349        17 days 14:09:00
# 12350       309 days 07:59:00

# %%
recency_df = temp_df["Recency"].apply(lambda x: x.days)

# %%
recency_df.head()
# Out:
# Customer ID
# 12346    324
# 12347      1
# 12348     74
# 12349     17
# 12350    309
# Name: Recency, dtype: int64

# %%
temp_df = df.groupby(["Customer ID","Invoice"]).agg({"Invoice":"count"})

# %%
temp_df.groupby("Customer ID").agg({"Invoice":"count"}).head()
# Out:
#              Invoice
# Customer ID
# 12346              2
# 12347              7
# 12348              4
# 12349              1
# 12350              1

# %%
freq_df = temp_df.groupby("Customer ID").agg({"Invoice":"count"})
freq_df.rename(columns={"Invoice": "Frequency"}, inplace = True)
freq_df.head()
# Out:
#              Frequency
# Customer ID
# 12346                2
# 12347                7
# 12348                4
# 12349                1
# 12350                1

# %%
monetary_df = df.groupby("Customer ID").agg({"TotalPrice":"sum"})

# %%
monetary_df.head()
# Out:
#              TotalPrice
# Customer ID
# 12346                 0
# 12347              4310
# 12348              1797
# 12349              1758
# 12350               334

# %%
monetary_df.rename(columns={"TotalPrice": "Monetary"}, inplace = True)

# %%
print(recency_df.shape,freq_df.shape,monetary_df.shape)
# Out:
# (4372,) (4372, 1) (4372, 1)

# %%
rfm = pd.concat([recency_df, freq_df, monetary_df],  axis=1)

# %%
rfm.head()
# Out:
#              Recency  Frequency  Monetary
# Customer ID
# 12346            324          2         0
# 12347              1          7      4310
# 12348             74          4      1797
# 12349             17          1      1758
# 12350            309          1       334

# %%
rfm["RecencyScore"] = pd.qcut(rfm['Recency'], 5, labels = [5, 4, 3, 2, 1])

# %%
rfm["FrequencyScore"] = pd.qcut(rfm['Frequency'].rank(method="first"), 5, labels = [1, 2, 3, 4, 5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-f0905462c075> in <module>
# ----> 1 rfm["FrequencyScore"] = pd.qcut(rfm['Frequency'].rank(method="first"), 5, labels = [1, 2, 3, 4, 5, 6])
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     346         include_lowest=True,
#     347         dtype=dtype,
# --> 348         duplicates=duplicates,
#     349     )
#     350
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     409             if len(labels) != len(bins) - 1:
#     410                 raise ValueError(
# --> 411                     "Bin labels must be one fewer than the number of bin edges"
#     412                 )
#     413
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %%
rfm["MonetaryScore"] = pd.qcut(rfm['Monetary'], 5, labels = [1, 2, 3, 4, 5])

# %%
rfm.head()
# Out:
#              Recency  Frequency  Monetary RecencyScore MonetaryScore
# Customer ID
# 12346            324          2         0            1             1
# 12347              1          7      4310            5             5
# 12348             74          4      1797            2             4
# 12349             17          1      1758            4             4
# 12350            309          1       334            1             2

# %%
(rfm['RecencyScore'].astype(str) + 
 rfm['FrequencyScore'].astype(str) + 
 rfm['MonetaryScore'].astype(str)).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FrequencyScore'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-ad3964b272d8> in <module>
#       1 (rfm['RecencyScore'].astype(str) +
# ----> 2  rfm['FrequencyScore'].astype(str) +
#       3  rfm['MonetaryScore'].astype(str)).head()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FrequencyScore'

# %%
rfm["RFM_SCORE"] = rfm['RecencyScore'].astype(str) + rfm['FrequencyScore'].astype(str) + rfm['MonetaryScore'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FrequencyScore'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-ad4f617661fd> in <module>
# ----> 1 rfm["RFM_SCORE"] = rfm['RecencyScore'].astype(str) + rfm['FrequencyScore'].astype(str) + rfm['MonetaryScore'].astype(str)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FrequencyScore'

# %%
rfm.head()
# Out:
#              Recency  Frequency  Monetary RecencyScore MonetaryScore
# Customer ID
# 12346            324          2         0            1             1
# 12347              1          7      4310            5             5
# 12348             74          4      1797            2             4
# 12349             17          1      1758            4             4
# 12350            309          1       334            1             2

# %%
rfm.describe().T

# %%
rfm[rfm["RFM_SCORE"] == "555"].head()

# %%
rfm[rfm["RFM_SCORE"] == "111"].head()

# %%
seg_map = {
    r'[1-2][1-2]': 'Hibernating',
    r'[1-2][3-4]': 'At Risk',
    r'[1-2]5': 'Can\'t Loose',
    r'3[1-2]': 'About to Sleep',
    r'33': 'Need Attention',
    r'[3-4][4-5]': 'Loyal Customers',
    r'41': 'Promising',
    r'51': 'New Customers',
    r'[4-5][2-3]': 'Potential Loyalists',
    r'5[4-5]': 'Champions'
}

# %%
rfm['Segment'] = rfm['RecencyScore'].astype(str) + rfm['FrequencyScore'].astype(str)
rfm['Segment'] = rfm['Segment'].replace(seg_map, regex=True)
rfm.head()

# %%
rfm[["Segment", "Recency","Frequency","Monetary"]].groupby("Segment").agg(["mean","count"])

# %%
rfm[rfm["Segment"] == "Need Attention"].head()

# %%
rfm[rfm["Segment"] == "New Customers"].index

# %%
new_df = pd.DataFrame()
new_df["NewCustomerID"] = rfm[rfm["Segment"] == "New Customers"].index

# %%
new_df.head()

# %%
new_df.to_csv("new_customers.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-46d7e242ac8c> in <module>
# ----> 1 new_df.to_csv("new_customers.csv")
#
# NameError: name 'new_df' is not defined
